# %%
# %matplotlib inline
from sqlalchemy import create_engine
import pandas as pd
from __future__ import print_function
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import csv
from collections import defaultdict
import datetime as dt


import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

# %% [markdown]
# #Loading Features
# We'll use the number of calls for that day, as well as some external information we've pulled in (such as weather).

# %%
db_uri = "postgresql://jnance:@localhost:5432/cfs"

engine = create_engine(db_uri)

# %%
call_df = pd.read_sql("""
SELECT
  date_trunc('day', time_received) AS date_received,
  COUNT(*) AS count
FROM call
WHERE cancelled=FALSE
GROUP BY date_trunc('day', time_received);
""", engine, index_col='date_received')
call_df['year_received'] = call_df.index.year
call_df['month_received'] = call_df.index.month
call_df['week_received'] = call_df.index.week
call_df['day_received'] = call_df.index.day
call_df['dow_received'] = call_df.index.dayofweek

print(call_df.shape)
call_df.head()
# Out:
# (365, 6)
#                count  year_received  month_received  week_received  \
# date_received
# 2014-01-01       828           2014               1              1
# 2014-01-02       851           2014               1              1
# 2014-01-03       956           2014               1              1
# 2014-01-04       686           2014               1              1
# 2014-01-05       663           2014               1              1
#
#                day_received  dow_received
# date_received
# 2014-01-01                1             2
# 2014-01-02                2             3
# 2014-01-03                3             4
# 2014-01-04                4             5
# 2014-01-05                5             6

# %%
weather_data = defaultdict(dict)
all_types = set()
with open('../csv_data/rdu_weather.csv', 'r') as f:
    reader = csv.reader(f)
    first = True
    for row in reader:
        if first:
            first = False
            header = row
            continue
        
        date = dt.datetime.strptime(row[header.index('date')], '%Y-%m-%dT%H:%M:%S')
        datatype = row[header.index('datatype')]
        value = row[header.index('value')]
        
        weather_data[date][datatype] = value
        all_types.add(datatype)

weather_data_by_date = defaultdict(list)
for key in weather_data.keys():
    for datatype in all_types:
        if datatype in weather_data[key]:
            weather_data_by_date[datatype].append(weather_data[key][datatype])
        else:
            weather_data_by_date[datatype].append(None)
            
weather_df = pd.DataFrame(weather_data_by_date, index=pd.Series(list(weather_data.keys())))
print(weather_df.shape)
weather_df.head()
# Out:
# (365, 16)
#            AWND PRCP SNOW SNWD TAVG TMAX TMIN WDF2 WDF5 WSF2 WSF5  WT01  WT02  \
# 2014-04-14   48    8    0    0  205  244  172  200  200   98  134     1  None
# 2014-07-20   18  236    0    0  228  272  200  100  130   40   58     1  None
# 2014-03-05   18    0    0    0   18   67  -10   50   40   45   58  None  None
# 2014-01-10   16  145    0    0   58   72   39  270  280   45   63  None  None
# 2014-11-30   39    0    0    0   89  189   22  230  240  103  139  None  None
#
#             WT03  WT04  WT08
# 2014-04-14  None  None  None
# 2014-07-20  None  None  None
# 2014-03-05  None  None  None
# 2014-01-10  None  None  None
# 2014-11-30  None  None  None

# %%
df = call_df.join(weather_df)
print(df.shape)
df.head()
# Out:
# (365, 22)
#                count  year_received  month_received  week_received  \
# date_received
# 2014-01-01       828           2014               1              1
# 2014-01-02       851           2014               1              1
# 2014-01-03       956           2014               1              1
# 2014-01-04       686           2014               1              1
# 2014-01-05       663           2014               1              1
#
#                day_received  dow_received AWND PRCP  SNOW SNWD  ...  TMIN  \
# date_received                                                   ...
# 2014-01-01                1             2   11    0     0    0  ...   -16
# 2014-01-02                2             3   12   84  None    0  ...    28
# 2014-01-03                3             4   33    0     0    0  ...   -55
# 2014-01-04                4             5   10    0     0    0  ...   -71
# 2014-01-05                5             6   22    0     0    0  ...    28
#
#               WDF2 WDF5 WSF2 WSF5  WT01  WT02  WT03  WT04  WT08
# date_received
# 2014-01-01     200  210   40   58  None  None  None  None  None
# 2014-01-02     310  320   58   98     1  None  None  None  None
# 2014-01-03     300  310   98  143  None  None  None  None  None
# 2014-01-04     120  120   36   58  None  None  None  None  None
# 2014-01-05     180  180   72   94  None  None  None  None  None
#
# [5 rows x 22 columns]

# %% [markdown]
# Output the finished features to a csv so we can load them in easier later.

# %%
df.to_csv('../csv_data/time_series_analysis.csv')

# %% [markdown]
# #Performing the analysis with statmodels

# %%
df.plot(figsize=(12,8));

# %%
fig = plt.figure(figsize=(30,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.values.squeeze(), lags=100, ax=ax1)

# %%
arima_mod20 = sm.tsa.ARIMA(df, (1,0,0)).fit()
print(arima_mod20.params)
# Out:
# const          789.926219
# ar.L1.count      0.418099
# dtype: float64

# %%
sm.tsa.stattools.arma_order_select_ic(df, max_ar=14, max_ma=14)
# Out:
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:443: RuntimeWarning: Inverting hessian failed, no bse or cov_params available
#   warn(warndoc, RuntimeWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/jnance/anaconda/lib/python3.4/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# {'bic':              0            1            2            3            4   \
#  0   4477.288607  4391.139539  4395.423101  4393.946539  4399.368002
#  1   4413.238616  4396.026919  4402.503894  4399.390638  4401.281811
#  2   4387.721197  4391.863860          NaN          NaN          NaN
#  3   4392.721508  4399.005079  4314.108798  4314.176691  4320.520602
#  4   4393.741026  4399.640542  4350.242306  4332.551148  4296.993168
#  5   4399.638143  4375.714594          NaN          NaN  4234.922279
#  6   4353.456113  4336.973356  4320.838198  4297.345001  4234.795372
#  7   4309.158577  4308.568640  4302.700814          NaN          NaN
#  8   4304.843713  4309.192374  4285.395234          NaN          NaN
#  9   4308.496800  4314.068456  4279.409752          NaN          NaN
#  10  4314.024048  4319.930051  4286.982765          NaN          NaN
#  11  4319.773882  4325.565881  4314.540275  4320.095940          NaN
#  12  4324.994664  4321.520141  4286.662239          NaN  4267.637423
#  13  4320.389823  4310.638023  4289.814792  4297.475474  4274.329544
#  14  4293.048136  4298.918829  4301.281625  4296.529632  4270.940588
#
#               5            6            7            8            9   \
#  0   4404.846939  4393.178657  4354.679903  4357.041608  4360.199187
#  1           NaN  4396.453523  4358.420007  4361.734302  4365.125233
#  2           NaN          NaN          NaN          NaN          NaN
#  3   4326.368485  4326.580955  4319.869597          NaN  4367.735647
#  4   4254.855556  4245.406703  4248.085877  4253.690580  4258.519502
#  5   4246.378540          NaN          NaN  4245.222198  4260.941586
#  6           NaN          NaN          NaN  4249.624206  4254.975351
#  7   4249.161859  4244.716481  4247.708977  4247.076485  4263.068255
#  8           NaN  4248.196392  4237.338065  4277.515416  4265.433881
#  9           NaN  4251.820627  4267.537566  4255.357865  4271.717965
#  10          NaN          NaN          NaN          NaN          NaN
#  11  4262.801990  4261.650610          NaN          NaN          NaN
#  12  4270.547753  4271.756918          NaN          NaN  4277.934772
#  13          NaN  4273.549013          NaN  4278.671695  4280.786968
#  14          NaN  4275.764346          NaN  4280.135329          NaN
#
#               10           11           12           13           14
#  0   4364.440360  4369.949094  4374.698527  4379.805634  4364.408710
#  1   4369.964398  4972.037954  4829.995636  4970.710433  4364.281481
#  2           NaN          NaN          NaN          NaN  4353.580820
#  3   4315.185168          NaN  4369.671473          NaN  4324.580241
#  4   4264.337767  4256.680560  4263.326546  4269.269965  4275.146166
#  5   4267.717523  4261.876906  4265.065573          NaN  4270.181625
#  6   4261.620669  4266.803008  4270.753453  4400.629666  4291.582720
#  7   4263.578835  4266.054505  4268.302193  4285.474676          NaN
#  8   4255.385345  4270.240076  4274.429230  4283.418417  4289.967009
#  9   4277.622420  4283.407288  4285.021553  4285.439582  4299.683028
#  10          NaN          NaN          NaN          NaN          NaN
#  11          NaN          NaN          NaN          NaN          NaN
#  12          NaN          NaN          NaN          NaN          NaN
#  13          NaN          NaN  4301.096317  4304.631725          NaN
#  14          NaN          NaN          NaN          NaN          NaN  ,
#  'bic_min_order': (6, 4)}
