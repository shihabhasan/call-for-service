# %% [markdown]
# #External Data Loading
#
# We can load in data from other external sources to aid in modeling and other tasks for this project.  We'll do that in this notebook (for now).

# %% [markdown]
# #Historical Weather Data
# Weather could have a large effect on crime, and it could be useful to include it in our models.  We can pull historical weather data for the Durham area using [this NOAA API](http://www.ncdc.noaa.gov/cdo-web/webservices/v2#gettingStarted).

# %%
import requests
import json
import csv
from pprint import pprint

API_token = "icxXgrAydpGZbNqZtPMpcsCPnIWcwQhu"  # <-- Jason's API token
headers = {'token': API_token}

# %% [markdown]
# First, we need to see all the stations in NC, so we can find the one closest to Durham.

# %%
stations_url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/stations'
stations_params = {'locationid': 'FIPS:37', 'limit': 1000, 'offset': 2000}

r = requests.get(stations_url, params=stations_params, headers=headers)

# %%
pprint(r.json())
# Out:
# {'metadata': {'resultset': {'count': 2161, 'limit': 1000, 'offset': 2000}},
#  'results': [{'datacoverage': 0.9996,
#               'elevation': 190.2,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USC00448257',
#               'latitude': 36.533333,
#               'longitude': -79.533333,
#               'maxdate': '1919-12-31',
#               'mindate': '1917-08-01',
#               'name': 'SWANSONVILLE, NC US'},
#              {'datacoverage': 0.9874,
#               'elevation': 6.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NBAC',
#               'latitude': 34.5328,
#               'longitude': -77.7219,
#               'maxdate': '2015-08-23',
#               'mindate': '2002-05-01',
#               'name': 'BACK ISLAND NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9803,
#               'elevation': 7.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NBFT',
#               'latitude': 35.5206,
#               'longitude': -76.9314,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-01-01',
#               'name': 'BEAUFORT NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 881.5,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NBUS',
#               'latitude': 35.7694,
#               'longitude': -82.1917,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'BUSICK NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9937,
#               'elevation': 176.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NCAS',
#               'latitude': 36.3856,
#               'longitude': -79.2919,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-08-01',
#               'name': 'CASWELL GAME LANDS N. CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 640.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NCHE',
#               'latitude': 35.3333,
#               'longitude': -83.8167,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'CHEOAH NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9938,
#               'elevation': 6.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NCRN',
#               'latitude': 34.7833,
#               'longitude': -76.8667,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'CROATAN NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 172.2,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NDUK',
#               'latitude': 35.9667,
#               'longitude': -79.0917,
#               'maxdate': '2015-08-24',
#               'mindate': '2000-03-01',
#               'name': 'DUKE FOREST NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.8729,
#               'elevation': 3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NFAI',
#               'latitude': 35.5417,
#               'longitude': -76.2231,
#               'maxdate': '2015-08-05',
#               'mindate': '2003-02-01',
#               'name': 'FAIRFIELD NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 143,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NFBR',
#               'latitude': 35.1397,
#               'longitude': -79.0644,
#               'maxdate': '2015-08-24',
#               'mindate': '2000-02-01',
#               'name': 'FORT BRAGG NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.975,
#               'elevation': 12.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NGRC',
#               'latitude': 36.0175,
#               'longitude': -76.8917,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-04-01',
#               'name': 'GREENS CROSS NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 487.7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NGRF',
#               'latitude': 35.7564,
#               'longitude': -82.0439,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'GRANDFATHER NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9737,
#               'elevation': 792.5,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NGUI',
#               'latitude': 35.2133,
#               'longitude': -82.59,
#               'maxdate': '2015-08-24',
#               'mindate': '1999-10-01',
#               'name': 'GUION FARM NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9803,
#               'elevation': 1158.2,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NHIG',
#               'latitude': 35.0836,
#               'longitude': -83.2178,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'HIGHLANDS NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.955,
#               'elevation': 12.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NHOF',
#               'latitude': 34.825,
#               'longitude': -77.3219,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-08-01',
#               'name': 'HOFMANN FOREST NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 853.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NJCY',
#               'latitude': 35.3167,
#               'longitude': -82.2,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-07-01',
#               'name': 'JACKSON CO NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9937,
#               'elevation': 228.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NLEX',
#               'latitude': 35.7922,
#               'longitude': -80.312,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-08-01',
#               'name': 'LEXINGTON NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9688,
#               'elevation': 914.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NLSP',
#               'latitude': 36.4,
#               'longitude': -81.2833,
#               'maxdate': '2013-05-15',
#               'mindate': '2002-10-01',
#               'name': 'LAUREL SPRINGS NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9737,
#               'elevation': 152.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NMTI',
#               'latitude': 35.3789,
#               'longitude': -80.9925,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-01-01',
#               'name': 'MOUNT ISLAND LAKE NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9889,
#               'elevation': 16.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NNAC',
#               'latitude': 34.0483,
#               'longitude': -78.2903,
#               'maxdate': '2015-08-24',
#               'mindate': '2000-12-01',
#               'name': 'NATURE CONSERVANCY NORTH CAROL, NC US'},
#              {'datacoverage': 0.9375,
#               'elevation': 780.3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NNCP',
#               'latitude': 35.8167,
#               'longitude': -81.9372,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-03-01',
#               'name': 'NORTH COVE PINNACLE N. CAROLIN, NC US'},
#              {'datacoverage': 0.9266,
#               'elevation': 6.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NNWB',
#               'latitude': 35.0967,
#               'longitude': -77.1108,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'NEW BERN NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 1.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NPOC',
#               'latitude': 35.7469,
#               'longitude': -76.5108,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-12-01',
#               'name': 'POCOSIN LAKES NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9568,
#               'elevation': 121.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NRCK',
#               'latitude': 34.96,
#               'longitude': -79.69,
#               'maxdate': '2013-06-03',
#               'mindate': '2000-02-01',
#               'name': 'ROCKINGHAM NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 726.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NREN',
#               'latitude': 36.2275,
#               'longitude': -81.2975,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-07-01',
#               'name': 'RENDEZVOUS MOUNTAIN NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9996,
#               'elevation': 32,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NRKM',
#               'latitude': 35.9731,
#               'longitude': -77.7986,
#               'maxdate': '2013-10-03',
#               'mindate': '2002-07-01',
#               'name': 'ROCKY MOUNT NORTH CAROLINA, NC US'},
#              {'datacoverage': 1,
#               'elevation': 321.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NRUT',
#               'latitude': 35.4286,
#               'longitude': -81.9394,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-05-01',
#               'name': 'RUTHERFORD CO NORTH CAROLI, NC US'},
#              {'datacoverage': 0.9871,
#               'elevation': 12.2,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NSND',
#               'latitude': 34.6119,
#               'longitude': -77.4875,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'SANDY RUN NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9633,
#               'elevation': 9.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NSUN',
#               'latitude': 34.0028,
#               'longitude': -77.9581,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-01-01',
#               'name': 'SUNNY POINT NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9621,
#               'elevation': 30.5,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NTUR',
#               'latitude': 34.6831,
#               'longitude': -78.5817,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-05-01',
#               'name': 'TURNBULL CREEK NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9602,
#               'elevation': 698.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NTUS',
#               'latitude': 35.04,
#               'longitude': -84.06,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'TUSQUITEE NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9938,
#               'elevation': 164.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NUWH',
#               'latitude': 35.3667,
#               'longitude': -79.8667,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'UWHARRIE TROY NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.8998,
#               'elevation': 658.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NWAY',
#               'latitude': 35.1667,
#               'longitude': -83.4031,
#               'maxdate': '2015-08-24',
#               'mindate': '2003-02-01',
#               'name': 'WAYAH NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9949,
#               'elevation': 30.5,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000NWHI',
#               'latitude': 34.3361,
#               'longitude': -78.7286,
#               'maxdate': '2015-08-24',
#               'mindate': '1999-09-01',
#               'name': 'WHITEVILLE NORTH CAROLINA, NC US'},
#              {'datacoverage': 0.9508,
#               'elevation': 1036.3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USR0000TCHE',
#               'latitude': 35.6197,
#               'longitude': -83.2069,
#               'maxdate': '2015-08-24',
#               'mindate': '2002-02-01',
#               'name': 'CHEROKEE TENNESSEE, NC US'},
#              {'datacoverage': 1,
#               'elevation': 171.3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00003758',
#               'latitude': 35.9705,
#               'longitude': -79.0931,
#               'maxdate': '2015-08-23',
#               'mindate': '2007-03-01',
#               'name': 'DURHAM 11 W, NC US'},
#              {'datacoverage': 1,
#               'elevation': 348.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00003810',
#               'latitude': 35.7425,
#               'longitude': -81.3819,
#               'maxdate': '2015-08-24',
#               'mindate': '1949-01-01',
#               'name': 'HICKORY FAA AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 645.3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00003812',
#               'latitude': 35.43194,
#               'longitude': -82.5375,
#               'maxdate': '2015-08-24',
#               'mindate': '1946-01-01',
#               'name': 'ASHEVILLE REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 33.2,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013713',
#               'latitude': 35.3444,
#               'longitude': -77.9647,
#               'maxdate': '2010-12-31',
#               'mindate': '1900-02-01',
#               'name': 'GOLDSBORO SEYMOUR JOHNSON AFB, NC US'},
#              {'datacoverage': 1,
#               'elevation': 66.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013714',
#               'latitude': 35.17389,
#               'longitude': -79.00889,
#               'maxdate': '2011-05-17',
#               'mindate': '1948-09-01',
#               'name': 'FAYETTEVILLE POPE AFB, NC US'},
#              {'datacoverage': 1,
#               'elevation': 126.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013722',
#               'latitude': 35.8923,
#               'longitude': -78.7819,
#               'maxdate': '2015-08-24',
#               'mindate': '1944-05-01',
#               'name': 'RALEIGH DURHAM INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 271.3,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013723',
#               'latitude': 36.0969,
#               'longitude': -79.9432,
#               'maxdate': '2015-08-24',
#               'mindate': '1928-11-01',
#               'name': 'GREENSBORO PIEDMONT TRIAD INTERNATIONAL AIRPORT, NC '
#                       'US'},
#              {'datacoverage': 1,
#               'elevation': 4.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013745',
#               'latitude': 35.21667,
#               'longitude': -75.71667,
#               'maxdate': '2010-12-31',
#               'mindate': '1893-01-01',
#               'name': 'HATTERAS, NC US'},
#              {'datacoverage': 0.997,
#               'elevation': 25.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013746',
#               'latitude': 35.96667,
#               'longitude': -77.8,
#               'maxdate': '1976-12-31',
#               'mindate': '1949-01-01',
#               'name': 'ROCKY MOUNT FAA AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 132,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013747',
#               'latitude': 36.41667,
#               'longitude': -78.15,
#               'maxdate': '1948-09-09',
#               'mindate': '1948-01-01',
#               'name': 'WARRENTON WEATHER BUREAU AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 10.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013748',
#               'latitude': 34.2675,
#               'longitude': -77.8997,
#               'maxdate': '2015-08-23',
#               'mindate': '1948-01-01',
#               'name': 'WILMINGTON INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 8.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013754',
#               'latitude': 34.9,
#               'longitude': -76.88333,
#               'maxdate': '2015-08-23',
#               'mindate': '1945-03-01',
#               'name': 'HAVELOCK CHERRY POINT MCAS, NC US'},
#              {'datacoverage': 0.1337,
#               'elevation': 13.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013761',
#               'latitude': 36.01667,
#               'longitude': -76.56667,
#               'maxdate': '1958-03-31',
#               'mindate': '1945-03-01',
#               'name': 'EDENTON NAAS, NC US'},
#              {'datacoverage': 0.9947,
#               'elevation': 7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013765',
#               'latitude': 36.1,
#               'longitude': -76.33333,
#               'maxdate': '1945-07-31',
#               'mindate': '1945-03-01',
#               'name': 'HARVEY POINT NAAS, NC US'},
#              {'datacoverage': 1,
#               'elevation': 4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013766',
#               'latitude': 35.91722,
#               'longitude': -75.7,
#               'maxdate': '2015-08-22',
#               'mindate': '1945-03-01',
#               'name': 'MANTEO DARE CO AIRPORT, NC US'},
#              {'datacoverage': 0.4969,
#               'elevation': 7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013774',
#               'latitude': 36.25,
#               'longitude': -76.13333,
#               'maxdate': '1957-06-27',
#               'mindate': '1945-02-01',
#               'name': 'WEEKSVILLE NAF, NC US'},
#              {'datacoverage': 1,
#               'elevation': 36.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013776',
#               'latitude': 34.608,
#               'longitude': -79.0591,
#               'maxdate': '2015-08-23',
#               'mindate': '1948-09-01',
#               'name': 'LUMBERTON REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013786',
#               'latitude': 36.26056,
#               'longitude': -76.175,
#               'maxdate': '2015-08-24',
#               'mindate': '1948-09-01',
#               'name': 'ELIZABETH CITY COAST GUARD AIR STATION, NC US'},
#              {'datacoverage': 1,
#               'elevation': 682.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013872',
#               'latitude': 35.5954,
#               'longitude': -82.5568,
#               'maxdate': '2015-06-30',
#               'mindate': '1876-08-01',
#               'name': 'ASHEVILLE, NC US'},
#              {'datacoverage': 1,
#               'elevation': 221.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00013881',
#               'latitude': 35.2236,
#               'longitude': -80.9552,
#               'maxdate': '2015-08-24',
#               'mindate': '1939-07-01',
#               'name': 'CHARLOTTE DOUGLAS INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 242.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00053870',
#               'latitude': 35.19667,
#               'longitude': -81.15583,
#               'maxdate': '2015-08-23',
#               'mindate': '1999-02-01',
#               'name': 'GASTONIA MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 207,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00053872',
#               'latitude': 35.01694,
#               'longitude': -80.62056,
#               'maxdate': '2015-08-23',
#               'mindate': '1999-02-01',
#               'name': 'MONROE AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 655.6,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00053877',
#               'latitude': 35.4945,
#               'longitude': -82.6142,
#               'maxdate': '2015-08-23',
#               'mindate': '2001-06-01',
#               'name': 'ASHEVILLE 8 SSW, NC US'},
#              {'datacoverage': 1,
#               'elevation': 641,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00053878',
#               'latitude': 35.4185,
#               'longitude': -82.5567,
#               'maxdate': '2015-08-23',
#               'mindate': '2001-06-01',
#               'name': 'ASHEVILLE 13 S, NC US'},
#              {'datacoverage': 1,
#               'elevation': 5.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093719',
#               'latitude': 35.0677,
#               'longitude': -77.048,
#               'maxdate': '2015-08-23',
#               'mindate': '1948-09-01',
#               'name': 'NEW BERN CRAVEN CO REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 0.6662,
#               'elevation': 28.7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093726',
#               'latitude': 35.31667,
#               'longitude': -77.63333,
#               'maxdate': '1957-06-28',
#               'mindate': '1955-07-01',
#               'name': 'KINSTON STALLINGS FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 7.9,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093727',
#               'latitude': 34.70842,
#               'longitude': -77.43966,
#               'maxdate': '2015-08-22',
#               'mindate': '1955-01-01',
#               'name': 'NEW RIVER MCAF, NC US'},
#              {'datacoverage': 1,
#               'elevation': 3.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093729',
#               'latitude': 35.2326,
#               'longitude': -75.6219,
#               'maxdate': '2015-08-23',
#               'mindate': '1957-03-01',
#               'name': 'CAPE HATTERAS BILLY MITCHELL AIRPORT, NC US'},
#              {'datacoverage': 0.5582,
#               'elevation': 74.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093737',
#               'latitude': 35.13333,
#               'longitude': -78.93333,
#               'maxdate': '1978-08-31',
#               'mindate': '1961-07-01',
#               'name': 'FORT BRAGG SIMMONS ARMY AIR FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 56.7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093740',
#               'latitude': 34.99139,
#               'longitude': -78.88028,
#               'maxdate': '2015-08-23',
#               'mindate': '1998-04-01',
#               'name': 'FAYETTEVILLE REGIONAL AIRPORT GRANNIS FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 6.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093743',
#               'latitude': 34.68333,
#               'longitude': -77.03333,
#               'maxdate': '2014-11-06',
#               'mindate': '1980-10-01',
#               'name': 'SWANSBORO BOGUE FIELD MCAF, NC US'},
#              {'datacoverage': 1,
#               'elevation': 48.8,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093759',
#               'latitude': 35.855,
#               'longitude': -77.89306,
#               'maxdate': '2015-08-23',
#               'mindate': '2000-10-01',
#               'name': 'ROCKY MOUNT WILSON AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 3.4,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093765',
#               'latitude': 34.73361,
#               'longitude': -76.66056,
#               'maxdate': '2015-08-23',
#               'mindate': '2000-04-01',
#               'name': 'BEAUFORT MICHAEL J SMITH FIELD, NC US'},
#              {'datacoverage': 0.9425,
#               'elevation': 9.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093776',
#               'latitude': 34.88333,
#               'longitude': -76.86667,
#               'maxdate': '1997-12-25',
#               'mindate': '1996-07-01',
#               'name': 'CHERRY POINT MCAS ASOS 2, NC US'},
#              {'datacoverage': 1,
#               'elevation': 78,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093781',
#               'latitude': 36.43944,
#               'longitude': -77.70972,
#               'maxdate': '2010-12-31',
#               'mindate': '1998-11-01',
#               'name': 'ROANOKE RAPIDS HALIFAX CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 67.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093782',
#               'latitude': 34.79167,
#               'longitude': -79.36611,
#               'maxdate': '2015-08-22',
#               'mindate': '1998-06-01',
#               'name': 'LAURINBURG MAXTON AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 188.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093783',
#               'latitude': 36.04667,
#               'longitude': -79.47694,
#               'maxdate': '2015-08-23',
#               'mindate': '1998-07-01',
#               'name': 'BURLINGTON ALAMANCE REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 156.1,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093785',
#               'latitude': 35.93333,
#               'longitude': -79.06417,
#               'maxdate': '2015-08-23',
#               'mindate': '1999-07-01',
#               'name': 'CHAPEL HILL WILLIAMS AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 295.7,
#               'elevationUnit': 'METERS',
#               'id': 'GHCND:USW00093807',
#               'latitude': 36.13361,
#               'longitude': -80.22222,
#               'maxdate': '2015-08-22',
#               'mindate': '1899-06-01',
#               'name': 'WINSTON SALEM REYNOLDS AIRPORT, NC US'},
#              {'datacoverage': 0.95,
#               'elevation': 34.1,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KAKQ',
#               'latitude': 36.98389,
#               'longitude': -77.0075,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-01-01',
#               'name': 'NORFOLK RICH, VA US'},
#              {'datacoverage': 0.95,
#               'elevation': 70.4,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KCAE',
#               'latitude': 33.94861,
#               'longitude': -81.11861,
#               'maxdate': '2015-08-26',
#               'mindate': '1994-06-27',
#               'name': 'COLUMBIA, SC US'},
#              {'datacoverage': 0.95,
#               'elevation': 874.2,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KFCX',
#               'latitude': 37.02417,
#               'longitude': -80.27417,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-02-13',
#               'name': 'ROANOKE, VA US'},
#              {'datacoverage': 0.95,
#               'elevation': 261.5,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KFFC',
#               'latitude': 33.36333,
#               'longitude': -84.56583,
#               'maxdate': '2015-08-26',
#               'mindate': '1994-11-09',
#               'name': 'ATLANTA, GA US'},
#              {'datacoverage': 0.95,
#               'elevation': 286.5,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KGSP',
#               'latitude': 34.88306,
#               'longitude': -82.22028,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-04-19',
#               'name': 'GREER, SC US'},
#              {'datacoverage': 0.95,
#               'elevation': 536.4,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KHTX',
#               'latitude': 34.93056,
#               'longitude': -86.08361,
#               'maxdate': '2015-08-26',
#               'mindate': '1997-07-05',
#               'name': 'HUNTSVILLE, AL US'},
#              {'datacoverage': 0.95,
#               'elevation': 415.7,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KJKL',
#               'latitude': 37.59083,
#               'longitude': -83.31306,
#               'maxdate': '2015-08-26',
#               'mindate': '1996-08-14',
#               'name': 'JACKSON, KY US'},
#              {'datacoverage': 0.95,
#               'elevation': 19.5,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KLTX',
#               'latitude': 33.98917,
#               'longitude': -78.42917,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-05-11',
#               'name': 'WILMINGTON, NC US'},
#              {'datacoverage': 0.95,
#               'elevation': 9.4,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KMHX',
#               'latitude': 34.77583,
#               'longitude': -76.87639,
#               'maxdate': '2015-08-26',
#               'mindate': '1994-06-17',
#               'name': 'MOREHEAD CITY, NC US'},
#              {'datacoverage': 0.95,
#               'elevation': 407.5,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KMRX',
#               'latitude': 36.16833,
#               'longitude': -83.40194,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-05-11',
#               'name': 'KNOXVILLE, TN US'},
#              {'datacoverage': 0.95,
#               'elevation': 106.1,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KRAX',
#               'latitude': 35.66528,
#               'longitude': -78.49,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-05-04',
#               'name': 'RALEIGH DURHAM, NC US'},
#              {'datacoverage': 0.95,
#               'elevation': 329.2,
#               'elevationUnit': 'METERS',
#               'id': 'NEXRAD:KRLX',
#               'latitude': 38.31194,
#               'longitude': -81.72389,
#               'maxdate': '2015-08-26',
#               'mindate': '1995-05-09',
#               'name': 'CHARLESTON, WV US'},
#              {'datacoverage': 1,
#               'elevation': 44.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:00231',
#               'latitude': 36.33,
#               'longitude': -77.635,
#               'maxdate': '2015-08-26',
#               'mindate': '2014-07-31',
#               'name': 'HALIFAX NORTHAMPTON REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 16.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:00290',
#               'latitude': 35.937,
#               'longitude': -77.547,
#               'maxdate': '2015-08-26',
#               'mindate': '2013-01-01',
#               'name': 'TARBORO EDGECOMBE AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 187.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:00340',
#               'latitude': 35.704,
#               'longitude': -79.504,
#               'maxdate': '2015-01-23',
#               'mindate': '2014-07-31',
#               'name': 'SILER CITY MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 5.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:00370',
#               'latitude': 35.02,
#               'longitude': -76.46,
#               'maxdate': '2015-08-26',
#               'mindate': '2014-07-31',
#               'name': 'PINEY ISLAND, NC US'},
#              {'datacoverage': 1,
#               'elevation': 91.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:00383',
#               'latitude': 35.017,
#               'longitude': -80.083,
#               'maxdate': '2015-08-26',
#               'mindate': '2013-01-01',
#               'name': 'ANSON CO AIRPORT JEFF CLOUD FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 41.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03702',
#               'latitude': 35,
#               'longitude': -77.98167,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'KENANSVILLE DUPLIN CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 6.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03703',
#               'latitude': 36.0275,
#               'longitude': -76.56694,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'EDENTON NORTHEAST REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 40.5,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03705',
#               'latitude': 34.60167,
#               'longitude': -78.57806,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ELIZABETHTOWN AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 40.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03708',
#               'latitude': 35.46028,
#               'longitude': -77.96472,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'GOLDSBORO WAYNE MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 205.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03709',
#               'latitude': 35.65361,
#               'longitude': -79.895,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ASHEBORO MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 160.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03711',
#               'latitude': 36.36139,
#               'longitude': -78.52889,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'HENDERSON OXFORD AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 60.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03712',
#               'latitude': 35.37861,
#               'longitude': -78.73361,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ERWIN HARNETT CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 50.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03713',
#               'latitude': 35.54083,
#               'longitude': -78.39028,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'SMITHFIELD JOHNSTON CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 140.5,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03720',
#               'latitude': 35.23722,
#               'longitude': -79.39111,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'MOORE CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 7.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03721',
#               'latitude': 33.92917,
#               'longitude': -78.07472,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'BRUNSWICK CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 185.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03722',
#               'latitude': 36.28472,
#               'longitude': -78.98417,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ROXBORO PERSON CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 75.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03723',
#               'latitude': 35.58222,
#               'longitude': -79.10111,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'SANFORD LEE CO REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 45.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03727',
#               'latitude': 34.97556,
#               'longitude': -78.36444,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'CLINTON SAMPSON CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 112.5,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03731',
#               'latitude': 36.02333,
#               'longitude': -78.33028,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'LOUISBURG FRANKLIN CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03736',
#               'latitude': 36.01833,
#               'longitude': -75.67139,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'KILL DEVIL HILLS FIRST FLIGHT AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 4.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03737',
#               'latitude': 36.39889,
#               'longitude': -76.01639,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'CURRITUCK CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 109.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03738',
#               'latitude': 34.89111,
#               'longitude': -79.75917,
#               'maxdate': '2015-08-25',
#               'mindate': '2005-01-01',
#               'name': 'ROCKINGHAM HAMLET AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 11.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03741',
#               'latitude': 35.57028,
#               'longitude': -77.04972,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-05-05',
#               'name': 'WARREN FIELD AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 171.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03758',
#               'latitude': 35.9705,
#               'longitude': -79.0931,
#               'maxdate': '2015-08-26',
#               'mindate': '2007-03-29',
#               'name': 'DURHAM 11 W, NC US'},
#              {'datacoverage': 1,
#               'elevation': 211.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03763',
#               'latitude': 36.43722,
#               'longitude': -79.85111,
#               'maxdate': '2015-08-26',
#               'mindate': '2006-10-24',
#               'name': 'ROCKINGHAM CO SHILOH AIRPORT, NC US'},
#              {'datacoverage': 0.93,
#               'elevation': 348.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03810',
#               'latitude': 35.7425,
#               'longitude': -81.3819,
#               'maxdate': '2015-08-26',
#               'mindate': '1949-01-01',
#               'name': 'HICKORY FAA AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 645.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:03812',
#               'latitude': 35.43194,
#               'longitude': -82.5375,
#               'maxdate': '2015-08-26',
#               'mindate': '1948-01-01',
#               'name': 'ASHEVILLE REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 0.87,
#               'elevation': 33.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13713',
#               'latitude': 35.3444,
#               'longitude': -77.9647,
#               'maxdate': '2015-08-26',
#               'mindate': '1943-06-01',
#               'name': 'GOLDSBORO SEYMOUR JOHNSON AFB, NC US'},
#              {'datacoverage': 1,
#               'elevation': 66.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13714',
#               'latitude': 35.17389,
#               'longitude': -79.00889,
#               'maxdate': '2015-08-26',
#               'mindate': '1937-07-03',
#               'name': 'FAYETTEVILLE POPE AFB, NC US'},
#              {'datacoverage': 1,
#               'elevation': 126.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13722',
#               'latitude': 35.8923,
#               'longitude': -78.7819,
#               'maxdate': '2015-08-26',
#               'mindate': '1945-11-01',
#               'name': 'RALEIGH DURHAM INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 271.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13723',
#               'latitude': 36.0969,
#               'longitude': -79.9432,
#               'maxdate': '2015-08-26',
#               'mindate': '1945-11-01',
#               'name': 'GREENSBORO PIEDMONT TRIAD INTERNATIONAL AIRPORT, NC '
#                       'US'},
#              {'datacoverage': 1,
#               'elevation': 10.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13748',
#               'latitude': 34.2675,
#               'longitude': -77.8997,
#               'maxdate': '2015-08-26',
#               'mindate': '1942-06-01',
#               'name': 'WILMINGTON INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 8.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13754',
#               'latitude': 34.9,
#               'longitude': -76.88333,
#               'maxdate': '2015-08-26',
#               'mindate': '1945-03-01',
#               'name': 'HAVELOCK CHERRY POINT MCAS, NC US'},
#              {'datacoverage': 0.45,
#               'elevation': 4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13766',
#               'latitude': 35.91722,
#               'longitude': -75.7,
#               'maxdate': '2015-08-26',
#               'mindate': '1945-03-01',
#               'name': 'MANTEO DARE CO AIRPORT, NC US'},
#              {'datacoverage': 0.37,
#               'elevation': 36.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13776',
#               'latitude': 34.608,
#               'longitude': -79.0591,
#               'maxdate': '2015-08-26',
#               'mindate': '1949-01-01',
#               'name': 'LUMBERTON REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 7.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13783',
#               'latitude': 35.63333,
#               'longitude': -77.38333,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'GREENVILLE PITT GREENVILLE AIRPORT, NC US'},
#              {'datacoverage': 0.9,
#               'elevation': 4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13786',
#               'latitude': 36.26056,
#               'longitude': -76.175,
#               'maxdate': '2015-08-26',
#               'mindate': '1949-01-01',
#               'name': 'ELIZABETH CITY COAST GUARD AIR STATION, NC US'},
#              {'datacoverage': 1,
#               'elevation': 221.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:13881',
#               'latitude': 35.2236,
#               'longitude': -80.9552,
#               'maxdate': '2015-08-26',
#               'mindate': '1941-07-22',
#               'name': 'CHARLOTTE DOUGLAS INTERNATIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 242.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53870',
#               'latitude': 35.19667,
#               'longitude': -81.15583,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'GASTONIA MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 207,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53872',
#               'latitude': 35.01694,
#               'longitude': -80.62056,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'MONROE AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 655.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53877',
#               'latitude': 35.4945,
#               'longitude': -82.6142,
#               'maxdate': '2015-08-26',
#               'mindate': '2000-11-20',
#               'name': 'ASHEVILLE 8 SSW, NC US'},
#              {'datacoverage': 1,
#               'elevation': 641,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53878',
#               'latitude': 35.4185,
#               'longitude': -82.5567,
#               'maxdate': '2015-08-26',
#               'mindate': '2000-11-21',
#               'name': 'ASHEVILLE 13 S, NC US'},
#              {'datacoverage': 1,
#               'elevation': 223.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53888',
#               'latitude': 35.78111,
#               'longitude': -80.30361,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'LEXINGTON DAVIDSON CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 328.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53890',
#               'latitude': 35.42806,
#               'longitude': -81.935,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'RUTHERFORD CO MARCHMAN FIELD AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 969.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53892',
#               'latitude': 36.43222,
#               'longitude': -81.41944,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'JEFFERSON ASHE CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 266.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:53899',
#               'latitude': 35.48306,
#               'longitude': -81.16111,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'LINCOLNTON LINCOLN CO REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 214.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63801',
#               'latitude': 35.38222,
#               'longitude': -80.49056,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'CONCORD REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 380.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63807',
#               'latitude': 36.45972,
#               'longitude': -80.55278,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'MOUNT AIRY SURRY CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 516.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63811',
#               'latitude': 35.195,
#               'longitude': -83.86528,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ANDREWS MURPHY AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 235.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63812',
#               'latitude': 35.64583,
#               'longitude': -80.52028,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'SALISBURY ROWAN CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 294.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63816',
#               'latitude': 35.765,
#               'longitude': -80.95667,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'STATESVILLE MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 910.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63819',
#               'latitude': 36.2,
#               'longitude': -81.65,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'BOONE WATAUGA CO HOSPITAL HELIPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 396.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63821',
#               'latitude': 36.22278,
#               'longitude': -81.09833,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'WILKES CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 185.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63824',
#               'latitude': 35.41667,
#               'longitude': -80.15056,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'STANLY CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 258.2,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63843',
#               'latitude': 35.25556,
#               'longitude': -81.60111,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'SHELBY MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 615.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63844',
#               'latitude': 35.2225,
#               'longitude': -83.41917,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'MACON CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 387.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:63859',
#               'latitude': 35.82139,
#               'longitude': -81.61056,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-04-19',
#               'name': 'MORGANTON LENOIR FOOTHILLS REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 0.94,
#               'elevation': 5.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93719',
#               'latitude': 35.0677,
#               'longitude': -77.048,
#               'maxdate': '2015-08-26',
#               'mindate': '1949-01-01',
#               'name': 'NEW BERN CRAVEN CO REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 0.7,
#               'elevation': 28.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93726',
#               'latitude': 35.31667,
#               'longitude': -77.63333,
#               'maxdate': '2015-08-26',
#               'mindate': '1954-11-01',
#               'name': 'KINSTON STALLINGS FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 7.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93727',
#               'latitude': 34.70842,
#               'longitude': -77.43966,
#               'maxdate': '2015-08-26',
#               'mindate': '1955-01-03',
#               'name': 'NEW RIVER MCAF, NC US'},
#              {'datacoverage': 0.97,
#               'elevation': 3.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93729',
#               'latitude': 35.2326,
#               'longitude': -75.6219,
#               'maxdate': '2015-08-26',
#               'mindate': '1957-03-01',
#               'name': 'CAPE HATTERAS BILLY MITCHELL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 74.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93737',
#               'latitude': 35.13333,
#               'longitude': -78.93333,
#               'maxdate': '2015-08-26',
#               'mindate': '1961-07-01',
#               'name': 'FORT BRAGG SIMMONS ARMY AIR FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 56.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93740',
#               'latitude': 34.99139,
#               'longitude': -78.88028,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'FAYETTEVILLE REGIONAL AIRPORT GRANNIS FIELD, NC US'},
#              {'datacoverage': 0.38,
#               'elevation': 6.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93743',
#               'latitude': 34.68333,
#               'longitude': -77.03333,
#               'maxdate': '2015-08-26',
#               'mindate': '1980-10-01',
#               'name': 'SWANSBORO BOGUE FIELD MCAF, NC US'},
#              {'datacoverage': 1,
#               'elevation': 114.6,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93747',
#               'latitude': 35.03333,
#               'longitude': -79.5,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-04-20',
#               'name': 'FORT BRAGG MACKALL ARMY AIR FIELD, NC US'},
#              {'datacoverage': 1,
#               'elevation': 29.3,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93753',
#               'latitude': 34.83333,
#               'longitude': -77.61667,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'JACKSONVILLE ALBERT ELLIS AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 48.8,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93759',
#               'latitude': 35.855,
#               'longitude': -77.89306,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'ROCKY MOUNT WILSON AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 3.4,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93765',
#               'latitude': 34.73361,
#               'longitude': -76.66056,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'BEAUFORT MICHAEL J SMITH FIELD, NC US'},
#              {'datacoverage': 0.5,
#               'elevation': 9.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93776',
#               'latitude': 34.88333,
#               'longitude': -76.86667,
#               'maxdate': '2015-08-25',
#               'mindate': '2015-02-21',
#               'name': 'CHERRY POINT MCAS ASOS 2, NC US'},
#              {'datacoverage': 1,
#               'elevation': 78,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93781',
#               'latitude': 36.43944,
#               'longitude': -77.70972,
#               'maxdate': '2009-06-25',
#               'mindate': '2005-01-01',
#               'name': 'ROANOKE RAPIDS HALIFAX CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 67.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93782',
#               'latitude': 34.79167,
#               'longitude': -79.36611,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'LAURINBURG MAXTON AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 188.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93783',
#               'latitude': 36.04667,
#               'longitude': -79.47694,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'BURLINGTON ALAMANCE REGIONAL AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 156.1,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93785',
#               'latitude': 35.93333,
#               'longitude': -79.06417,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'CHAPEL HILL WILLIAMS AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 20.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93796',
#               'latitude': 36.2975,
#               'longitude': -77.17083,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'AHOSKIE TRI CO AIRPORT, NC US'},
#              {'datacoverage': 1,
#               'elevation': 29.9,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93799',
#               'latitude': 34.27278,
#               'longitude': -78.71472,
#               'maxdate': '2015-08-26',
#               'mindate': '2005-01-01',
#               'name': 'WHITEVILLE COLUMBUS CO MUNICIPAL AIRPORT, NC US'},
#              {'datacoverage': 0.91,
#               'elevation': 295.7,
#               'elevationUnit': 'METERS',
#               'id': 'WBAN:93807',
#               'latitude': 36.13361,
#               'longitude': -80.22222,
#               'maxdate': '2015-08-26',
#               'mindate': '1948-01-01',
#               'name': 'WINSTON SALEM REYNOLDS AIRPORT, NC US'}]}

# %% [markdown]
# After digging around, we can find a few stations that could have useful info.  We can examine the datasets these provide.

# %%
# Useful datasets: there are many with 'DURHAM' in the name, and not all are useful

durham_id = 'GHCND:USW00003758'
duke_forest_id = 'GHCND:USR0000NDUK'
rdu_radar_id = 'NEXRAD:KRAX'
rdu_id = 'GHCND:USW00013722'

# %%
datasets_url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/datasets'
dataset_params = {
    'stationid': rdu_id,
    'limit': 1000
}
r = requests.get(datasets_url, params=dataset_params, headers=headers)

# %%
pprint(r.json())
# Out:
# {'metadata': {'resultset': {'count': 6, 'limit': 1000, 'offset': 1}},
#  'results': [{'datacoverage': 1,
#               'id': 'GHCND',
#               'maxdate': '2015-08-25',
#               'mindate': '1763-01-01',
#               'name': 'Daily Summaries',
#               'uid': 'gov.noaa.ncdc:C00861'},
#              {'datacoverage': 1,
#               'id': 'GHCNDMS',
#               'maxdate': '2015-06-01',
#               'mindate': '1763-01-01',
#               'name': 'Monthly Summaries',
#               'uid': 'gov.noaa.ncdc:C00841'},
#              {'datacoverage': 1,
#               'id': 'NORMAL_ANN',
#               'maxdate': '2010-01-01',
#               'mindate': '2010-01-01',
#               'name': 'Normals Annual/Seasonal',
#               'uid': 'gov.noaa.ncdc:C00821'},
#              {'datacoverage': 1,
#               'id': 'NORMAL_DLY',
#               'maxdate': '2010-12-31',
#               'mindate': '2010-01-01',
#               'name': 'Normals Daily',
#               'uid': 'gov.noaa.ncdc:C00823'},
#              {'datacoverage': 1,
#               'id': 'NORMAL_HLY',
#               'maxdate': '2010-12-31',
#               'mindate': '2010-01-01',
#               'name': 'Normals Hourly',
#               'uid': 'gov.noaa.ncdc:C00824'},
#              {'datacoverage': 1,
#               'id': 'NORMAL_MLY',
#               'maxdate': '2010-12-01',
#               'mindate': '2010-01-01',
#               'name': 'Normals Monthly',
#               'uid': 'gov.noaa.ncdc:C00822'}]}

# %% [markdown]
# Now we can check out the actual data for a given station, once we know which data sets it has.
#
# Note that the values are in the following units:
#
# - PRCP = Precipitation (tenths of mm)
# - SNOW = Snowfall (mm)
# - SNWD = Snow depth (mm)
# - TMAX = Maximum temperature (tenths of degrees C)
# - TMIN = Minimum temperature (tenths of degrees C)

# %%
data_url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/data'
data_params = {
    'datasetid': 'GHCND',
    'stationid': rdu_id,
    'limit': 1000,
    'startdate': '2014-01-01',
    'enddate': '2014-12-31'
}
r = requests.get(data_url, params=data_params, headers=headers)

# %%
pprint(r.json())
# Out:
# {'metadata': {'resultset': {'count': 4171, 'limit': 1000, 'offset': 1}},
#  'results': [{'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 11},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 36},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 106},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -16},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 200},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 210},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 40},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-01T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 12},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 84},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 56},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 94},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 28},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 310},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 320},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 98},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-01-02T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 33},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 10},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 61},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -55},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 300},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 310},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 98},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-03T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 143},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 10},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -26},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 33},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -71},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 120},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 120},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 36},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-04T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 22},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 67},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 167},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 28},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 180},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 180},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-05T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 94},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 61},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 33},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 106},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 161},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -88},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 210},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 134},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 174},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-01-06T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 34},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -78},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -38},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -127},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 300},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 320},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-07T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 112},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 13},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -39},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 61},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -93},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 210},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 45},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-08T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 11},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 24},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 122},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -38},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 110},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 120},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 40},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-09T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 63},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 16},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 145},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 39},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 270},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 280},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 45},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-10T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 63},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 46},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 71},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 124},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 206},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 268},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-11T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 385},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 26},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 111},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 144},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 39},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 250},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 260},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-12T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 112},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 32},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 77},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 167},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 6},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 94},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-13T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 116},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 13},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 108},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 122},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 33},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 190},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 320},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 54},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-01-14T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 20},
#              {'attributes': 'T,,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 69},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 150},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 6},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 180},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 210},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-15T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 107},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 17},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 18},
#              {'attributes': 'T,,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 37},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 67},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 270},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 280},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 54},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-16T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 41},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 40},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 133},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -16},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 94},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-17T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 112},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 30},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 33},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 83},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -27},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 270},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 240},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-18T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 107},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 38},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 36},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 122},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -10},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 240},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 240},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-19T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 116},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 36},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 62},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 178},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -10},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 81},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-20T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 107},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 22},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 25},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 13},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 54},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 106},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -32},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 40},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 360},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 125},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-01-21T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 20},
#              {'attributes': 'T,,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'T,,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'T,,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -31},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -10},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -77},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 30},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 20},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 89},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-01-22T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 21},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -38},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-01-23T00:00:00',
#               'station': 'GHCND:USW00013722',
# ...
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-23T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 107},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 21},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 41},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 100},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -10},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 60},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 50},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 54},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 67},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-03-24T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 26},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 8},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 47},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 72},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 6},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 120},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 320},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 89},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-03-25T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 31},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 28},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 83},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -16},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 280},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 290},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-26T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 125},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 31},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 44},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 150},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': -43},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 210},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 76},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-27T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 130},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 30},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 79},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 130},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 206},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 67},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 220},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 230},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 98},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-28T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 125},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 25},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 124},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 159},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 189},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 133},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 250},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 270},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 112},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-29T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 165},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 47},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 58},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNWD',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': 'H,,S,',
#               'datatype': 'TAVG',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 108},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMAX',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 167},
#              {'attributes': ',,W,2400',
#               'datatype': 'TMIN',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 56},
#              {'attributes': ',,W,',
#               'datatype': 'WDF2',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 250},
#              {'attributes': ',,W,',
#               'datatype': 'WDF5',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 270},
#              {'attributes': ',,W,',
#               'datatype': 'WSF2',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 112},
#              {'attributes': ',,W,',
#               'datatype': 'WSF5',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 165},
#              {'attributes': ',,W,',
#               'datatype': 'WT01',
#               'date': '2014-03-30T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 1},
#              {'attributes': ',,W,',
#               'datatype': 'AWND',
#               'date': '2014-03-31T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 18},
#              {'attributes': ',,W,2400',
#               'datatype': 'PRCP',
#               'date': '2014-03-31T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0},
#              {'attributes': ',,W,',
#               'datatype': 'SNOW',
#               'date': '2014-03-31T00:00:00',
#               'station': 'GHCND:USW00013722',
#               'value': 0}]}

# %% [markdown]
# The RDU Airport station has a lot of info.  We'll save that it to a file so we don't have to keep hitting the API.

# %%
offset = 1
limit = 1000

while True:
    data_url = 'http://www.ncdc.noaa.gov/cdo-web/api/v2/data'
    data_params = {
        'datasetid': 'GHCND',
        'stationid': rdu_id,
        'limit': limit,
        'offset': offset,
        'startdate': '2014-01-01',
        'enddate': '2014-12-31'
    }
    r = requests.get(data_url, params=data_params, headers=headers)
    r_json = r.json()
    
    with open("../csv_data/rdu_weather.csv", 'a+') as f:
        writer = csv.writer(f)
        if offset == 1:
            keys = ['attributes', 'datatype', 'date', 'station', 'value']
        writer.writerow(keys)
        for row in r_json['results']:
            writer.writerow([row[key] for key in keys])
            
    offset += limit
    
    if offset > r_json['metadata']['resultset']['count']:
        break
